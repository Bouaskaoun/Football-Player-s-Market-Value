# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException, StaleElementReferenceException
import time
from pprint import pprint
import pandas as pd

# %%
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),options = options)
driver.set_window_size(1120, 1000)
url ='https://sofifa.com/?showCol%5B%5D=pi&showCol%5B%5D=ae&showCol%5B%5D=hi&showCol%5B%5D=wi&showCol%5B%5D=pf&showCol%5B%5D=oa&showCol%5B%5D=pt&showCol%5B%5D=bo&showCol%5B%5D=bp&showCol%5B%5D=gu&showCol%5B%5D=jt&showCol%5B%5D=le&showCol%5B%5D=vl&showCol%5B%5D=wg&showCol%5B%5D=rc&showCol%5B%5D=ta&showCol%5B%5D=cr&showCol%5B%5D=fi&showCol%5B%5D=he&showCol%5B%5D=sh&showCol%5B%5D=vo&showCol%5B%5D=ts&showCol%5B%5D=dr&showCol%5B%5D=cu&showCol%5B%5D=fr&showCol%5B%5D=lo&showCol%5B%5D=bl&showCol%5B%5D=to&showCol%5B%5D=ac&showCol%5B%5D=sp&showCol%5B%5D=ag&showCol%5B%5D=re&showCol%5B%5D=ba&showCol%5B%5D=tp&showCol%5B%5D=so&showCol%5B%5D=ju&showCol%5B%5D=st&showCol%5B%5D=sr&showCol%5B%5D=ln&showCol%5B%5D=te&showCol%5B%5D=ar&showCol%5B%5D=in&showCol%5B%5D=po&showCol%5B%5D=vi&showCol%5B%5D=pe&showCol%5B%5D=cm&showCol%5B%5D=td&showCol%5B%5D=ma&showCol%5B%5D=sa&showCol%5B%5D=sl&showCol%5B%5D=tg&showCol%5B%5D=gd&showCol%5B%5D=gh&showCol%5B%5D=gc&showCol%5B%5D=gp&showCol%5B%5D=gr&showCol%5B%5D=tt&showCol%5B%5D=bs&showCol%5B%5D=wk&showCol%5B%5D=sk&showCol%5B%5D=aw&showCol%5B%5D=dw&showCol%5B%5D=ir&showCol%5B%5D=bt&showCol%5B%5D=pac&showCol%5B%5D=sho&showCol%5B%5D=pas&showCol%5B%5D=dri&showCol%5B%5D=def&showCol%5B%5D=phy'
driver.get(url)
players =[]

columns = [col.text for col in driver.find_elements(By.XPATH,'.//tr[@class="persist-header"]/th')]

num_players = 100
while len(players) < num_players:
    time.sleep(3)
    players_rows = driver.find_elements(By.XPATH,'.//tbody[@class="list"]/tr')
    for index,player_row in enumerate(players_rows):
        print("Progress: {}".format("" + str(len(players)) + "/" + str(num_players)))
        if len(players) >= num_players:
            break

        try:
            NAME = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('NAME failed')
            
        try:
            AGE = player_row.find_element(By.XPATH,'.//td[@class="col col-ae"]').text
        except Exception:
            print('AGE failed')
            
        try:
            OVA = player_row.find_element(By.XPATH,'.//td[@class="col col-oa"]').text
        except Exception:
            print('OVA failed')
            
        try:
            POT = player_row.find_element(By.XPATH,'.//td[@class="col col-pt"]').text
        except Exception:
            print('POT failed')
            
        try:
            TEAM_CONTRACT = player_row.find_element(By.XPATH,'.//td[@class="col-name"][2]').text
        except Exception:
            print('TEAM_CONTRACT failed')
            
        try:
            ID = player_row.find_element(By.XPATH,'.//td[@class="col col-pi"]').text
        except Exception:
            print('ID failed')
            
        try:
            HEIGHT = player_row.find_element(By.XPATH,'.//td[@class="col col-hi"]').text
        except Exception:
            print('HEIGHT failed')
            
        try:
            WEIGHT = player_row.find_element(By.XPATH,'.//td[@class="col col-wi"]').text
        except Exception:
            print('WEIGHT failed')
            
        try:
            FOOT = player_row.find_element(By.XPATH,'.//td[@class="col col-pf"]').text
        except Exception:
            print('FOOT failed')
            
        try:
            BOV = player_row.find_element(By.XPATH,'.//td[@class="col col-bo"]').text
        except Exception:
            print('BOV failed')
            
        try:
            BP = player_row.find_element(By.XPATH,'.//td[@class="col col-bp"]').text
        except Exception:
            print('BP failed')
            
        try:
            GROWTH = player_row.find_element(By.XPATH,'.//td[@class="col col-gu"]').text
        except Exception:
            print('GROWTH failed')
            
        try:
            JOINED = player_row.find_element(By.XPATH,'.//td[@class="col col-jt"]').text
        except Exception:
            print('JOINED failed')
            
        try:
            LOAN_DATE_END = player_row.find_element(By.XPATH,'.//td[@class="col col-le"]').text
        except Exception:
            print('LOAN_DATE_END failed')
            
        try:
            VALUE = player_row.find_element(By.XPATH,'.//td[@class="col col-vl"]').text
        except Exception:
            print('VALUE failed')
            
        try:
            WAGE = player_row.find_element(By.XPATH,'.//td[@class="col col-wg"]').text
        except Exception:
            print('WAGE failed')
            
        try:
            RELEASE_CLAUSE = player_row.find_element(By.XPATH,'.//td[@class="col col-rc"]').text
        except Exception:
            print('RELEASE_CLAUSE failed')
            
        try:
            ATTACKING = player_row.find_element(By.XPATH,'.//td[@class="col col-ta"]').text
        except Exception:
            print('ATTACKING failed')
            
        try:
            CROSSING = player_row.find_element(By.XPATH,'.//td[@class="col col-cr"]').text
        except Exception:
            print('CROSSING failed')
            
        try:
            FINISHING = player_row.find_element(By.XPATH,'.//td[@class="col col-fi"]').text
        except Exception:
            print('FINISHING failed')
            
        try:
            HEADING_ACCURACY = player_row.find_element(By.XPATH,'.//td[@class="col col-he"]').text
        except Exception:
            print('HEADING_ACCURACY failed')
            
        try:
            SHORT_PASSING = player_row.find_element(By.XPATH,'.//td[@class="col col-sh"]').text
        except Exception:
            print('SHORT_PASSING failed')
            
        try:
            VOLLEYS = player_row.find_element(By.XPATH,'.//td[@class="col col-vo"]').text
        except Exception:
            print('VOLLEYS failed')
            
        try:
            SKILL = player_row.find_element(By.XPATH,'.//td[@class="col col-ts"]').text
        except Exception:
            print('SKILL failed')
            
        try:
            DRIBBLING = player_row.find_element(By.XPATH,'.//td[@class="col col-dr"]').text
        except Exception:
            print('DRIBBLING failed')
            
        try:
            CURVE = player_row.find_element(By.XPATH,'.//td[@class="col col-cu"]').text
        except Exception:
            print('CURVE failed')
            
        try:
            FK_ACCURACY = player_row.find_element(By.XPATH,'.//td[@class="col col-fr"]').text
        except Exception:
            print('FK_ACCURACY failed')
            
        try:
            LONG_PASSING = player_row.find_element(By.XPATH,'.//td[@class="col col-lo"]').text
        except Exception:
            print('LONG_PASSING failed')
            
        try:
            BALL_CONTROL = player_row.find_element(By.XPATH,'.//td[@class="col col-bl"]').text
        except Exception:
            print('BALL_CONTROL failed')
            
        try:
            MOVEMENT = player_row.find_element(By.XPATH,'.//td[@class="col col-to"]').text
        except Exception:
            print('MOVEMENT failed')
            
        try:
            ACCELERATION = player_row.find_element(By.XPATH,'.//td[@class="col col-ac"]').text
        except Exception:
            print('ACCELERATION failed')
            
        try:
            SPRINT_SPEED = player_row.find_element(By.XPATH,'.//td[@class="col col-sp"]').text
        except Exception:
            print('SPRINT_SPEED failed')
            
        try:
            AGILITY = player_row.find_element(By.XPATH,'.//td[@class="col col-ag"]').text
        except Exception:
            print('AGILITY failed')
            
        try:
            REACTIONS = player_row.find_element(By.XPATH,'.//td[@class="col col-re"]').text
        except Exception:
            print('REACTIONS failed')
            
        try:
            BALANCE = player_row.find_element(By.XPATH,'.//td[@class="col col-ba"]').text
        except Exception:
            print('BALANCE failed')
            
        try:
            POWER = player_row.find_element(By.XPATH,'.//td[@class="col col-tp"]').text
        except Exception:
            print('POWER failed')
            
        try:
            SHOT_POWER = player_row.find_element(By.XPATH,'.//td[@class="col col-so"]').text
        except Exception:
            print('SHOT_POWER failed')
            
        try:
            JUMPING = player_row.find_element(By.XPATH,'.//td[@class="col col-ju"]').text
        except Exception:
            print('JUMPING failed')
            
        try:
            STAMINA = player_row.find_element(By.XPATH,'.//td[@class="col col-st"]').text
        except Exception:
            print('STAMINA failed')
            
        try:
            STRENGTH = player_row.find_element(By.XPATH,'.//td[@class="col col-sr"]').text
        except Exception:
            print('STRENGTH failed')
            
        try:
            LONG_SHOTS = player_row.find_element(By.XPATH,'.//td[@class="col col-ln"]').text
        except Exception:
            print('LONG_SHOTS failed')
            
        try:
            MENTALITY = player_row.find_element(By.XPATH,'.//td[@class="col col-te"]').text
        except Exception:
            print('MENTALITY failed')
            
        try:
            AGGRESSION = player_row.find_element(By.XPATH,'.//td[@class="col col-ar"]').text
        except Exception:
            print('AGGRESSION failed')
            
        try:
            INTERCEPTIONS = player_row.find_element(By.XPATH,'.//td[@class="col col-in"]').text
        except Exception:
            print('INTERCEPTIONS failed')
            
        try:
            POSITIONING = player_row.find_element(By.XPATH,'.//td[@class="col col-po"]').text
        except Exception:
            print('POSITIONING failed')
            
        try:
            VISION = player_row.find_element(By.XPATH,'.//td[@class="col col-vi"]').text
        except Exception:
            print('VISION failed')
            
        try:
            PENALTIES = player_row.find_element(By.XPATH,'.//td[@class="col col-pe"]').text
        except Exception:
            print('PENALTIES failed')
            
        try:
            COMPOSURE = player_row.find_element(By.XPATH,'.//td[@class="col col-cm"]').text
        except Exception:
            print('COMPOSURE failed')
            
        try:
            DEFENDING = player_row.find_element(By.XPATH,'.//td[@class="col col-td"]').text
        except Exception:
            print('DEFENDING failed')
            
        try:
            MARKING = player_row.find_element(By.XPATH,'.//td[@class="col col-ma"]').text
        except Exception:
            print('MARKING failed')
            
        try:
            STANDING_TACKLE = player_row.find_element(By.XPATH,'.//td[@class="col col-sa"]').text
        except Exception:
            print('STANDING_TACKLE failed')
            
        try:
            SLIDING_TACKLE = player_row.find_element(By.XPATH,'.//td[@class="col col-sl"]').text
        except Exception:
            print('SLIDING_TACKLE failed')
            
        try:
            GOALKEEPING = player_row.find_element(By.XPATH,'.//td[@class="col col-tg"]').text
        except Exception:
            print('GOALKEEPING failed')
            
        try:
            GK_DIVING = player_row.find_element(By.XPATH,'.//td[@class="col col-gd"]').text
        except Exception:
            print('GK_DIVING failed')
            
        try:
            GK_HANDLING = player_row.find_element(By.XPATH,'.//td[@class="col col-gh"]').text
        except Exception:
            print('GK_HANDLING failed')
            
        try:
            GK_KICKING = player_row.find_element(By.XPATH,'.//td[@class="col col-gc"]').text
        except Exception:
            print('GK_KICKING failed')
            
        try:
            GK_POSITIONING = player_row.find_element(By.XPATH,'.//td[@class="col col-gp"]').text
        except Exception:
            print('GK_POSITIONING failed')
            
        try:
            GK_REFLEXES = player_row.find_element(By.XPATH,'.//td[@class="col col-gr"]').text
        except Exception:
            print('GK_REFLEXES failed')
            
        try:
            TOTAL = player_row.find_element(By.XPATH,'.//td[@class="col col-tt"]').text
        except Exception:
            print('TOTAL failed')
            
        try:
            BASE_STATS = player_row.find_element(By.XPATH,'.//td[@class="col col-bs"]').text
        except Exception:
            print('BASE_STATS failed')
            
        try:
            W_F = player_row.find_element(By.XPATH,'.//td[@class="col col-wk"]').text
        except Exception:
            print('W_F failed')
            
        try:
            S_M = player_row.find_element(By.XPATH,'.//td[@class="col col-sk"]').text
        except Exception:
            print('S_M failed')
            
        try:
            A_W = player_row.find_element(By.XPATH,'.//td[@class="col col-aw"]').text
        except Exception:
            print('A_W failed')
            
        try:
            D_W = player_row.find_element(By.XPATH,'.//td[@class="col col-dw"]').text
        except Exception:
            print('D_W failed')
            
        try:
            IR = player_row.find_element(By.XPATH,'.//td[@class="col col-ir"]').text
        except Exception:
            print('IR failed')
            
        try:
            BODY_TYPE = player_row.find_element(By.XPATH,'.//td[@class="col col-bt"]').text
        except Exception:
            print('BODY_TYPE failed')
            
        try:
            PAC = player_row.find_element(By.XPATH,'.//td[@class="col col-pac"]').text
        except Exception:
            print('PAC failed')
            
        try:
            SHO = player_row.find_element(By.XPATH,'.//td[@class="col col-sho"]').text
        except Exception:
            print('SHO failed')
            
        try:
            PAS = player_row.find_element(By.XPATH,'.//td[@class="col col-pas"]').text
        except Exception:
            print('PAS failed')
            
        try:
            DRI = player_row.find_element(By.XPATH,'.//td[@class="col col-dri"]').text
        except Exception:
            print('DRI failed')
            
        try:
            DEF = player_row.find_element(By.XPATH,'.//td[@class="col col-def"]').text
        except Exception:
            print('DEF failed')
            
        try:
            PHY = player_row.find_element(By.XPATH,'.//td[@class="col col-phy"]').text
        except Exception:
            print('PHY failed')
            
        players.append({'NAME':NAME,
                         'AGE':AGE,
                         'OVA':OVA,
                         'POT':POT,
                         'TEAM & CONTRACT':TEAM_CONTRACT,
                         'ID':ID,
                         'HEIGHT':HEIGHT,
                         'WEIGHT':WEIGHT,
                         'FOOT':FOOT,
                         'BOV':BOV,
                         'BP':BP,
                         'GROWTH':GROWTH,
                         'JOINED':JOINED,
                         'LOAN DATE END':LOAN_DATE_END,
                         'VALUE':VALUE,
                         'WAGE':WAGE,
                         'RELEASE CLAUSE':RELEASE_CLAUSE,
                         'ATTACKING':ATTACKING,
                         'CROSSING':CROSSING,
                         'FINISHING':FINISHING,
                         'HEADING ACCURACY':HEADING_ACCURACY,
                         'SHORT PASSING':SHORT_PASSING,
                         'VOLLEYS':VOLLEYS,
                         'SKILL':SKILL,
                         'DRIBBLING':DRIBBLING,
                         'CURVE':CURVE,
                         'FK ACCURACY':FK_ACCURACY,
                         'LONG PASSING':LONG_PASSING,
                         'BALL CONTROL':BALL_CONTROL,
                         'MOVEMENT':MOVEMENT,
                         'ACCELERATION':ACCELERATION,
                         'SPRINT SPEED':SPRINT_SPEED,
                         'AGILITY':AGILITY,
                         'REACTIONS':REACTIONS,
                         'BALANCE':BALANCE,
                         'POWER':POWER,
                         'SHOT POWER':SHOT_POWER,
                         'JUMPING':JUMPING,
                         'STAMINA':STAMINA,
                         'STRENGTH':STRENGTH,
                         'LONG SHOTS':LONG_SHOTS,
                         'MENTALITY':MENTALITY,
                         'AGGRESSION':AGGRESSION,
                         'INTERCEPTIONS':INTERCEPTIONS,
                         'POSITIONING':POSITIONING,
                         'VISION':VISION,
                         'PENALTIES':PENALTIES,
                         'COMPOSURE':COMPOSURE,
                         'DEFENDING':DEFENDING,
                         'MARKING':MARKING,
                         'STANDING TACKLE':STANDING_TACKLE,
                         'SLIDING TACKLE':SLIDING_TACKLE,
                         'GOALKEEPING':GOALKEEPING,
                         'GK DIVING':GK_DIVING,
                         'GK HANDLING':GK_HANDLING,
                         'GK KICKING':GK_KICKING,
                         'GK POSITIONING':GK_POSITIONING,
                         'GK REFLEXES':GK_REFLEXES,
                         'TOTAL':TOTAL,
                         'BASE STATS':BASE_STATS,
                         'W/F':W_F,
                         'SM':S_M,
                         'A/W':A_W,
                         'D/W':D_W,
                         'IR':IR,
                         'BODY TYPE':BODY_TYPE,
                         'PAC':PAC,
                         'SHO':SHO,
                         'PAS':PAS,
                         'DRI':DRI,
                         'DEF':DEF,
                         'PHY':PHY})
            
    try:
        next_page = driver.find_element(By.XPATH,'.//div[@class="pagination"]/a').click()
    except NoSuchElementException:
        print('next page failed')
# Out:
# Progress: 0/100
# Progress: 1/100
# Progress: 2/100
# Progress: 3/100
# Progress: 4/100
# Progress: 5/100
# Progress: 6/100
# Progress: 7/100
# Progress: 8/100
# Progress: 9/100
# Progress: 10/100
# Progress: 11/100
# Progress: 12/100
# Progress: 13/100
# Progress: 14/100
# Progress: 15/100
# Progress: 16/100
# Progress: 17/100
# Progress: 18/100
# Progress: 19/100
# Progress: 20/100
# Progress: 21/100
# Progress: 22/100
# Progress: 23/100
# Progress: 24/100
# Progress: 25/100
# Progress: 26/100
# Progress: 27/100
# Progress: 28/100
# Progress: 29/100
# Progress: 30/100
# Progress: 31/100
# Progress: 32/100
# Progress: 33/100
# Progress: 34/100
# Progress: 35/100
# Progress: 36/100
# Progress: 37/100
# Progress: 38/100
# Progress: 39/100
# Progress: 40/100
# Progress: 41/100
# Progress: 42/100
# Progress: 43/100
# Progress: 44/100
# Progress: 45/100
# Progress: 46/100
# Progress: 47/100
# Progress: 48/100
# Progress: 49/100
# Progress: 50/100
# Progress: 51/100
# Progress: 52/100
# ...

# %%
df = pd.DataFrame(players)

# %%
df.head()
# Out:
#                       NAME AGE OVA POT                   TEAM & CONTRACT  \
# 0              A. Isak\nST  21  82  86        Real Sociedad\n2019 ~ 2026
# 1        J. Gbamin\nCDM CM  25  76  76      PFC CSKA Moscow\n2019 ~ 2024
# 2               Merino\nCM  25  83  87        Real Sociedad\n2018 ~ 2025
# 3  21\n L. Dickmann\nRB RM  23  70  74                 SPAL\n2019 ~ 2022
# 4           E. Tapsoba\nCB  22  80  86  Bayer 04 Leverkusen\n2020 ~ 2026
#
#        ID HEIGHT WEIGHT   FOOT BOV  ...     A/W     D/W IR         BODY TYPE  \
# 0  233731  192cm   77kg  Right  84  ...    High     Low  2            Unique
# 1  214947  186cm   83kg  Right  76  ...  Medium  Medium  1     Normal (185+)
# 2  225193  189cm   83kg   Left  85  ...    High    High  1     Normal (185+)
# 3  229456  177cm   70kg  Right  70  ...    High  Medium  1  Normal (170-185)
# 4  247263  194cm   85kg  Right  82  ...  Medium    High  2     Normal (185+)
#
#   PAC SHO PAS DRI DEF PHY
# 0  84  82  69  80  29  69
# ...

# %%
df.to_csv('players_data.csv', index=False)
