# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException, StaleElementReferenceException
import time
from pprint import pprint
import pandas as pd

# %%
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),options = options)
driver.set_window_size(1120, 1000)
url ='https://sofifa.com/?showCol%5B%5D=phy&showCol%5B%5D=vl&showCol%5B%5D=pi&showCol%5B%5D=ae&showCol%5B%5D=hi&showCol%5B%5D=wi&showCol%5B%5D=pf&showCol%5B%5D=oa&showCol%5B%5D=pt&showCol%5B%5D=bo&showCol%5B%5D=bp&showCol%5B%5D=gu&showCol%5B%5D=jt&showCol%5B%5D=le&showCol%5B%5D=wg&showCol%5B%5D=rc&showCol%5B%5D=ta&showCol%5B%5D=cr&showCol%5B%5D=dr&showCol%5B%5D=ts&showCol%5B%5D=cu&showCol%5B%5D=vo&showCol%5B%5D=sh&showCol%5B%5D=he&showCol%5B%5D=fi&showCol%5B%5D=ba&showCol%5B%5D=bl&showCol%5B%5D=to&showCol%5B%5D=lo&showCol%5B%5D=fr&showCol%5B%5D=ac&showCol%5B%5D=sp&showCol%5B%5D=ag&showCol%5B%5D=re&showCol%5B%5D=tp&showCol%5B%5D=so&showCol%5B%5D=ju&showCol%5B%5D=st&showCol%5B%5D=sr&showCol%5B%5D=ln&showCol%5B%5D=cm&showCol%5B%5D=vi&showCol%5B%5D=pe&showCol%5B%5D=in&showCol%5B%5D=po&showCol%5B%5D=ar&showCol%5B%5D=te&showCol%5B%5D=td&showCol%5B%5D=ma&showCol%5B%5D=sa&showCol%5B%5D=sl&showCol%5B%5D=tg&showCol%5B%5D=gc&showCol%5B%5D=gh&showCol%5B%5D=gp&showCol%5B%5D=gd&showCol%5B%5D=gr&showCol%5B%5D=bs&showCol%5B%5D=wk&showCol%5B%5D=tt&showCol%5B%5D=aw&showCol%5B%5D=pac&showCol%5B%5D=bt&showCol%5B%5D=sho&showCol%5B%5D=ir&showCol%5B%5D=sk&showCol%5B%5D=dw&showCol%5B%5D=pas&showCol%5B%5D=dri&showCol%5B%5D=def'
driver.get(url)
players =[]

columns = [col.text for col in driver.find_elements(By.XPATH,'.//tr[@class="persist-header"]/th')]

num_players = 1000
while len(players) < num_players:
    time.sleep(3)
    players_rows = driver.find_elements(By.XPATH,'.//tbody[@class="list"]/tr')
    for index,player_row in enumerate(players_rows):
        print("Progress: {}".format("" + str(len(players)) + "/" + str(num_players)))
        if len(players) >= num_players:
            break

        try:
            NAME = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            AGE = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            OVA = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            POT = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            TEAM_CONTRACT = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            ID = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            HEIGHT = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            WEIGHT = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            FOOT = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            BOV = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            BP = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            GROWTH = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            JOINED = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            LOAN_DATE_END = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            VALUE = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            WAGE = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            RELEASE_CLAUSE = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            ATTACKING = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            CROSSING = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            FINISHING = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            HEADING_ACCURACY = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            SHORT_PASSING = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            VOLLEYS = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            SKILL = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            DRIBBLING = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            CURVE = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            FK_ACCURACY = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            LONG_PASSING = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            BALL_CONTROL = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            MOVEMENT = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            ACCELERATION = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            SPRINT_SPEED = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            AGILITY = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            REACTIONS = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            BALANCE = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            POWER = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            SHOT_POWER = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            JUMPING = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            STAMINA = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            STRENGTH = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            LONG_SHOTS = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            MENTALITY = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            AGGRESSION = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            INTERCEPTIONS = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            POSITIONING = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            VISION = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            PENALTIES = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            COMPOSURE = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            DEFENDING = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            MARKING = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            STANDING_TACKLE = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            SLIDING_TACKLE = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            GOALKEEPING = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            GK_DIVING = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            GK_HANDLING = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            GK_KICKING = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            GK_POSITIONING = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            GK_REFLEXES = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            TOTAL = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            BASE_STATS = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            W_F = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            S_M = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            A_W = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            D_W = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            IR = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            BODY_TYPE = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            PAC = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            SHO = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            PAS = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            DRI = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            DEF = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        try:
            PHY = player_row.find_element(By.XPATH,'.//td[@class="col-name"][1]').text
        except Exception:
            print('name failed')
            
        players.append({'NAME':NAME,
                         'AGE':AGE,
                         'OVA':OVA,
                         'POT':POT,
                         'TEAM & CONTRACT':TEAM_CONTRACT,
                         'ID':ID,
                         'HEIGHT':HEIGHT,
                         'WEIGHT':WEIGHT,
                         'FOOT':FOOT,
                         'BOV':BOV,
                         'BP':BP,
                         'GROWTH':GROWTH,
                         'JOINED':JOINED,
                         'LOAN DATE END':LOAN_DATE_END,
                         'VALUE':VALUE,
                         'WAGE':WAGE,
                         'RELEASE CLAUSE':RELEASE_CLAUSE,
                         'ATTACKING':ATTACKING,
                         'CROSSING':CROSSING,
                         'FINISHING':FINISHING,
                         'HEADING ACCURACY':HEADING_ACCURACY,
                         'SHORT PASSING':SHORT_PASSING,
                         'VOLLEYS':VOLLEYS,
                         'SKILL':SKILL,
                         'DRIBBLING':DRIBBLING,
                         'CURVE':CURVE,
                         'FK ACCURACY':FK_ACCURACY,
                         'LONG PASSING':LONG_PASSING,
                         'BALL CONTROL':BALL_CONTROL,
                         'MOVEMENT':MOVEMENT,
                         'ACCELERATION':ACCELERATION,
                         'SPRINT SPEED':SPRINT_SPEED,
                         'AGILITY':AGILITY,
                         'REACTIONS':REACTIONS,
                         'BALANCE':BALANCE,
                         'POWER':POWER,
                         'SHOT POWER':SHOT_POWER,
                         'JUMPING':JUMPING,
                         'STAMINA':STAMINA,
                         'STRENGTH':STRENGTH,
                         'LONG SHOTS':LONG_SHOTS,
                         'MENTALITY':MENTALITY,
                         'AGGRESSION':AGGRESSION,
                         'INTERCEPTIONS':INTERCEPTIONS,
                         'POSITIONING':POSITIONING,
                         'VISION':VISION,
                         'PENALTIES':PENALTIES,
                         'COMPOSURE':COMPOSURE,
                         'DEFENDING':DEFENDING,
                         'MARKING':MARKING,
                         'STANDING TACKLE':STANDING_TACKLE,
                         'SLIDING TACKLE':SLIDING_TACKLE,
                         'GOALKEEPING':GOALKEEPING,
                         'GK DIVING':GK_DIVING,
                         'GK HANDLING':GK_HANDLING,
                         'GK KICKING':GK_KICKING,
                         'GK POSITIONING':GK_POSITIONING,
                         'GK REFLEXES':GK_REFLEXES,
                         'TOTAL':TOTAL,
                         'BASE STATS':BASE_STATS,
                         'W/F':W_F,
                         'SM':S_M,
                         'A/W':A_W,
                         'D/W':D_W,
                         'IR':IR,
                         'BODY TYPE':BODY_TYPE,
                         'PAC':PAC,
                         'SHO':SHO,
                         'PAS':PAS,
                         'DRI':DRI,
                         'DEF':DEF,
                         'PHY':PHY})
            
    try:
        next_page = driver.find_element(By.XPATH,'.//div[@class="pagination"]/a[@class="next_page"]').click()
    except NoSuchElementException:
        print('next page failed')
# Out:
# ['',
#  'NAME',
#  'AGE',
#  'OVA',
#  'POT',
#  'TEAM & CONTRACT',
#  'ID',
#  'HEIGHT',
#  'WEIGHT',
#  'FOOT',
#  'BOV',
#  'BP',
#  'GROWTH',
#  'JOINED',
#  'LOAN DATE END',
#  'VALUE',
#  'WAGE',
#  'RELEASE CLAUSE',
#  'ATTACKING',
#  'CROSSING',
#  'FINISHING',
#  'HEADING ACCURACY',
#  'SHORT PASSING',
#  'VOLLEYS',
#  'SKILL',
#  'DRIBBLING',
#  'CURVE',
#  'FK ACCURACY',
#  'LONG PASSING',
#  'BALL CONTROL',
#  'MOVEMENT',
#  'ACCELERATION',
#  'SPRINT SPEED',
#  'AGILITY',
#  'REACTIONS',
#  'BALANCE',
#  'POWER',
#  'SHOT POWER',
#  'JUMPING',
#  'STAMINA',
#  'STRENGTH',
#  'LONG SHOTS',
#  'MENTALITY',
#  'AGGRESSION',
#  'INTERCEPTIONS',
#  'POSITIONING',
#  'VISION',
#  'PENALTIES',
#  'COMPOSURE',
#  'DEFENDING',
#  'MARKING',
#  'STANDING TACKLE',
#  'SLIDING TACKLE',
#  'GOALKEEPING',
#  'GK DIVING',
#  'GK HANDLING',
#  'GK KICKING',
#  'GK POSITIONING',
#  'GK REFLEXES',
#  'TOTAL',
#  'BASE STATS',
#  'W/F',
#  'SM',
#  'A/W',
#  'D/W',
#  'IR',
# ...
