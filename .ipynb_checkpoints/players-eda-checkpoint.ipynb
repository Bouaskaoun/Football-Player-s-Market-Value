# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('player_list.csv')

# %%
df.head(10)
# Out:
#              Name  Age  Overall  Potential                      Team  Height  \
# 0  Z. Ibrahimović   37       85         85                     Milan   196.0
# 1       A. Kanno    29       62         62                  Al Fayha   180.0
# 2         Brahim    19       74         86               Real Madrid   170.0
# 3       M. Aarons   19       73         85              Norwich City   178.0
# 4       J. David    19       77         88                  KAA Gent   178.0
# 5       M. Ginter   25       82         83  Borussia Mönchengladbach   190.0
# 6      S. Tonali    19       77         91                   Brescia   180.0
# 7        O. Kabak   19       77         86             FC Schalke 04   185.0
# 8     J. Sancho     19       86         94         Borussia Dortmund   180.0
# 9      A. Lallana   31       78         78                 Liverpool   178.0
#
#    Weight    Foot  Best_Overall Position  ...  GK_Reflexes  Total_Stats  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17779 entries, 0 to 17778
# Data columns (total 64 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              17779 non-null  object
#  1   Age               17779 non-null  int64
#  2   Overall           17779 non-null  int64
#  3   Potential         17779 non-null  int64
#  4   Team              17779 non-null  object
#  5   Height            17779 non-null  float64
#  6   Weight            17779 non-null  float64
#  7   Foot              17779 non-null  object
#  8   Best_Overall      17779 non-null  int64
#  9   Position          17779 non-null  object
#  10  Growth            17779 non-null  int64
#  11  Value             17779 non-null  float64
#  12  Wage              17779 non-null  float64
#  13  Release_Clause    17779 non-null  float64
#  14  Attacking         17779 non-null  int64
#  15  Crossing          17779 non-null  int64
# ...

# %%
df.describe()
# Out:
#                 Age       Overall     Potential        Height        Weight  \
# count  17779.000000  17779.000000  17779.000000  17779.000000  17779.000000
# mean      22.228922     62.527476     70.803589    180.624107     74.044941
# std        4.075507      7.796487      6.553878      6.732665      6.936865
# min       16.000000     45.000000     46.000000    155.000000     50.000000
# 25%       19.000000     57.000000     66.000000    175.000000     70.000000
# 50%       21.000000     62.000000     71.000000    180.000000     74.000000
# 75%       24.000000     67.000000     75.000000    185.000000     78.000000
# max       45.000000     94.000000     95.000000    211.000000    110.000000
#
#        Best_Overall        Growth         Value          Wage  Release_Clause  \
# count  17779.000000  17779.000000  17779.000000  17779.000000    17779.000000
# mean      62.948254      8.276112      1.993736      0.007271        3.414558
# ...

# %%
df.isnull().sum()
# Out:
# Name         0
# Age          0
# Overall      0
# Potential    0
# Team         0
#             ..
# SHO          0
# PAS          0
# DRI          0
# DEF          0
# PHY          0
# Length: 64, dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Overall', 'Potential', 'Team', 'Height', 'Weight',
#        'Foot', 'Best_Overall', 'Position', 'Growth', 'Value', 'Wage',
#        'Release_Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading_Accuracy', 'Short_Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK_Accuracy', 'Long_Passing', 'Ball_Control', 'Movement',
#        'Acceleration', 'Sprint_Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot_Power', 'Jumping', 'Stamina', 'Strength', 'Long_Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing_Tackle',
#        'Sliding_Tackle', 'Goalkeeping', 'GK_Diving', 'GK_Handling',
#        'GK_Kicking', 'GK_Positioning', 'GK_Reflexes', 'Total_Stats',
#        'Base_Stats', 'Int_Reputation', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF',
#        'PHY'],
#       dtype='object')

# %%
sns.histplot(df.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.relplot(x='Age', y='Value', kind='line', data=df)
sns.relplot(x='Age', y='Value', data=df)

# %%
df.nlargest(5,columns='Value')[['Name','Team','Value']]
# Out:
#             Name                 Team  Value
# 211   Neymar Jr   Paris Saint-Germain  105.5
# 58    L. Messi           FC Barcelona   95.5
# 95   K. Mbappé    Paris Saint-Germain   93.5
# 218  V. van Dijk            Liverpool   90.0
# 337   E. Hazard           Real Madrid   90.0

# %%
df.nlargest(5,columns='Overall')[['Name','Team','Overall']]
# Out:
#                    Name                 Team  Overall
# 58           L. Messi           FC Barcelona       94
# 396  Cristiano Ronaldo              Juventus       93
# 211          Neymar Jr   Paris Saint-Germain       92
# 194            J. Oblak      Atlético Madrid       91
# 218         V. van Dijk            Liverpool       91
